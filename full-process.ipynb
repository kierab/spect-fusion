130000,2025.541232500,2035.091335000,2044.641437500,2054.191540000,2063.741642500,2073.291745000,2082.841847500,2092.391950000,2101.942052500,2111.492155000,2121.042257500,2130.592360000,2140.142462500,2149.692565000,2159.242667500,2168.792770000,2178.342872500,2187.892975000,2197.443077500,2206.993180000,2216.543282500,2226.093385000,2235.643487500,2245.193590000,2254.743692500,2264.293795000,2273.843897500,2283.394000000,2292.944102500,2302.494205000,2312.044307500,2321.594410000,2331.144512500,2340.694615000,2350.244717500,2359.794820000,2369.344922500,2378.895025000,2388.445127500,2397.995230000,2407.545332500,2417.095435000,2426.645537500,2436.195640000,2445.745742500,2455.295845000,2464.845947500,2474.396050000,2483.946152500,2493.496255000,2503.046357500,2512.596460000,2522.146562500,2531.696665000,2541.246767500,2550.796870000,2560.346972500,2569.897075000,2579.447177500,2588.997280000,2598.547382500,2608.097485000,2617.647587500,2627.197690000,2636.747792500,2646.297895000,2655.847997500,2665.398100000,2674.948202500,2684.498305000,2694.048407500,2703.598510000,2713.148612500,2722.698715000,2732.248817500]

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize 
from scipy.ndimage import zoom
import matplotlib.patches as patche
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
fp_hyper = 'hyper/reorder_272_4080_640_U16.bin'
fp_swir = 'swir/Reorder_288_4111_384_U16.bin'

im_hyper = np.fromfile(fp_hyper,dtype='uint16')
im_hyper = (im_hyper-np.min(im_hyper))/(np.max(im_hyper)-np.min(im_hyper)) #nomralised
im_hyper = im_hyper.reshape([272,4080,640])

# %%
im_hyper =  np.transpose(im_hyper,(0,2,1))
plt.imshow(im_hyper[100,:,:])
plt.show()

# %%
im_swir = np.fromfile(fp_swir,dtype='uint16')
im_swir = (im_swir-np.min(im_swir))/(np.max(im_swir)-np.min(im_swir)) #nomralised
im_swir = im_swir.reshape([288,4111,384])

# %%
im_swir =  np.transpose(im_swir,(0,2,1))
im_swir = np.fliplr(im_swir)

plt.imshow(im_swir[100,:,:])
plt.show()

# %%
#take smaller crops of the same size from both\

#1 remove shit from sides of swir
plt.figure(figsize=(20,10))
swir = im_swir[:,:,91:im_swir.shape[2]-20]
plt.imshow(swir[100,:,:])

# %%
#2 clean up sides of hyper
plt.figure(figsize=(20,10))
hyp = im_hyper[:,:,35:im_hyper.shape[2]-45]
plt.imshow(hyp[100,:,:])

# %%
#ensure that htey are the same size, aligned etc
print('swir, hyp shape')
print(swir.shape, hyp.shape)
# print(wavelengths_swir[107])
# Out:
# swir, hyp shape
# (288, 384, 4000) (272, 640, 4000)

# %%
resized = zoom(hyp,(1,0.6,1))

# %%
print(swir.shape, resized.shape)
# Out:
# (288, 384, 4000) (272, 384, 4000)

# %%
# show resized nano image
plt.figure(figsize=(20,10))
plt.imshow(resized[250,:,:])

# %%
##concatenate the data
SWIR_INDEX = 107 # which wavelength index to slice swir data at
swir_crop = swir[SWIR_INDEX:,:,:]  # take 95th wavelength and onwards, as before this just rubbish n noise
fuse = np.concatenate((resized,swir_crop),axis=0)
# swir_crop.shape

# %%
fuse.shape
# Out:
# (453, 384, 4000)

# %%
plt.figure(figsize=(20,10))
plt.imshow(fuse[300,:,:])

# %%
#create bounding box arondn an object
# tree_xy = (3470,270)
# tree2_xy = (300,100)
# road_xy = (800,270)
# box_size = 100

# interest_obj = tree2_xy

# fig,ax = plt.subplots()
# # fig = plt.figure(figsize=(20,10))
# # plt.figure(figsize=(20,10))
# plot = ax.imshow(fuse[300,:,:].T)
# box_size = 100
# box = patches.Rectangle(interest_obj,box_size,box_size,lw=0.5,ec='r',fc="none")
# ax.add_patch(box)
# plt.show()

# %%
# select areas to train with 
tree1 = fuse[:,200:300,1900:2000]
tree2 = fuse[:,90:190,300:400]
tree3 = fuse[:,50:100,2100:2200]
road1 = fuse[:,300:380,800:900]
road2 = fuse[:,100:200,850:950]
dead_grass1 = fuse[:,150:250,3000:3100]
# dead_grass2 = fuse[:,int(330*0.6):int(430*0.6),2812:2906]
plt.imshow(road2[100,:,:])

# %%
#make training lists
#probs convert this into a function


# create a list of all the spectra present in the roi

# def spectra_list(roi)
#     tmp = []
#     for i in range(tree1[0,:,:].shape[1]):
#         for j in range(tree1[0,:,:].shape[0]):
#             spectra = tree1[:,j,i]
#             tmp.append([1, *spectra])
#     tree1_list = np.array(tmp)
#     return 

training = []
tmp = []
for i in range(tree1[0,:,:].shape[1]):
    for j in range(tree1[0,:,:].shape[0]):
        spectra = tree1[:,j,i]
        tmp.append([1, *spectra])
tree1_list = np.array(tmp)
training.append(tree1_list)

tmp = []
for i in range(tree2[0,:,:].shape[1]):
    for j in range(tree2[0,:,:].shape[0]):
        spectra = tree2[:,j,i]
        tmp.append([1, *spectra])
tree2_list = np.array(tmp)
training.append(tree2_list)

tmp = []
for i in range(tree3[0,:,:].shape[1]):
    for j in range(tree3[0,:,:].shape[0]):
        spectra = tree3[:,j,i]
        tmp.append([1, *spectra])
tree3_list = np.array(tmp)
training.append(tree3_list)

tmp = []
for i in range(road1[0,:,:].shape[1]):
    for j in range(road1[0,:,:].shape[0]):
        spectra = road1[:,j,i]
        tmp.append([2, *spectra])
road1_list = np.array(tmp)
training.append(road1_list)

tmp = []
for i in range(road2[0,:,:].shape[1]):
    for j in range(road2[0,:,:].shape[0]):
        spectra = road2[:,j,i]
        tmp.append([2, *spectra])
road2_list = np.array(tmp)
training.append(road2_list)


tmp = []
for i in range(dead_grass1[0,:,:].shape[1]):
    for j in range(dead_grass1[0,:,:].shape[0]):
        spectra = dead_grass1[:,j,i]
        tmp.append([3, *spectra])
dead_grass1_list = np.array(tmp)
training.append(dead_grass1_list)

# tmp = []
# for i in range(dead_grass2[0,:,:].shape[1]):
#     for j in range(dead_grass2[0,:,:].shape[0]):
#         spectra = dead_grass2[:,j,i]
#         tmp.append([3, *spectra])
# dead_grass2_list = np.array(tmp)
# training.append(dead_grass2_list)


# plt.plot(np.array(np.arange(0,dead_grass1_list[0].shape[0])),dead_grass1_list[3333])
# dead_grass1_list[0][0]

# %%
len(training)
# Out:
# 6

# %%
#add all the training data into a dataframe
df = pd.DataFrame(np.concatenate(training), columns=[['class']+list(np.arange(0,fuse.shape[0]))])
df.tail()
# Out:
#       class             0         1         2         3         4         5  \
# 52995   3.0  2.010052e-18  0.011593  0.012386  0.015204  0.016757  0.018648
# 52996   3.0  3.070516e-18  0.010469  0.016092  0.016944  0.016944  0.021637
# 52997   3.0  5.360524e-19  0.010776  0.012349  0.017329  0.016420  0.021825
# 52998   3.0  1.322636e-18  0.008604  0.014738  0.015025  0.010394  0.017724
# 52999   3.0  4.921509e-19  0.010327  0.012510  0.016150  0.014684  0.010991
#
#               6         7         8  ...       443       444       445  \
# 52995  0.017424  0.022655  0.020558  ...  0.019000  0.021289  0.020600
# 52996  0.021823  0.025538  0.026244  ...  0.020311  0.021178  0.022867
# 52997  0.022213  0.023711  0.023377  ...  0.021689  0.022689  0.020889
# 52998  0.017836  0.020846  0.018939  ...  0.022467  0.022978  0.021956
# 52999  0.017340  0.023709  0.023202  ...  0.023933  0.024778  0.024178
#
#             446       447       448       449       450       451       452
# ...

# %%
#divide into attributes and labels
train = df.iloc[:,1:454].values
labels = df.iloc[:,0].values #labels

# %%
#choosing a test area to test training
test_area = fuse[:,100:200,2950:3050]
plt.imshow(test_area[40,:,:])

# %%
tmp = []
for i in range(test_area[0,:,:].shape[1]):
    for j in range(test_area[0,:,:].shape[0]):
        spectra = test_area[:,j,i]
        tmp.append(spectra)
test_area_list = np.array(tmp)
test_area_list = np.reshape(test_area_list,(test_area.shape[1],test_area.shape[2],test_area.shape[0]))

cover = np.zeros((test_area.shape[1],test_area.shape[2],3))
cover.shape
# Out:
# (100, 100, 3)

# %%
plt.plot(np.array(np.arange(test_area_list[40,40,:].shape[0])),test_area_list[40,40,:])

# %%
clf = RandomForestClassifier()
clf.fit(train,labels)
# Out:
# RandomForestClassifier()

# %%
test_area = fuse[:,:,700:1000]
tmp = []
for i in range(test_area[0,:,:].shape[1]):
    for j in range(test_area[0,:,:].shape[0]):
        spectra = test_area[:,j,i]
        tmp.append(spectra)
test_area_list = np.array(tmp)
test_area_list = np.reshape(test_area_list,(test_area.shape[1],test_area.shape[2],test_area.shape[0]))

cover = np.zeros((test_area.shape[1],test_area.shape[2],3))
cover.shape
# Out:
# (384, 300, 3)

# %%
for i in range(cover.shape[1]):
    for j in range(cover.shape[0]):
        pred = clf.predict(test_area[:,j,i].reshape(1,-1))[0]
        if (pred == 1): 
            cover[j][i][0] = 0
            cover[j][i][1] = 255 #green for alive
            cover[j][i][2] = 0
        
        
        if (pred == 2): 
            cover[j][i][0] = 138
            cover[j][i][1] = 138 #grey  for road
            cover[j][i][2] = 138
            
        
        
        if (pred == 3): 
            cover[j][i][0] = 255 #red dead
            cover[j][i][1] = 0
            cover[j][i][2] = 0

plt.imshow(cover)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(test_area[200,:,:])

# %%
#plot specsig
object = fuse[:,interest_obj[0]:interest_obj[0]+box_size,interest_obj[1]:interest_obj[1]+box_size]
reflectance = np.array([np.mean(layer) for layer in object])
wl_nano = np.array(wavelengths_nano)
wl_swir = np.array(wavelengths_swir)
wavelengths = np.concatenate((wl_nano,wl_swir[SWIR_INDEX:]))

# print(wavelengths.shape,reflectance.shape)

plt.figure(figsize=(15,7))
plt.xlabel('wavelength (nm)')
plt.ylabel('avg irradience')
plt.title(f'fused spectral sig (avg) of bounding box contents')
plt.plot(wavelengths,reflectance,linewidth=2)
plt.show()

# %%
object.shape
# plt.plot(wavelengths,object[:,2,2])
# plt.plot(wavelengths,object[:,22,44])
# for layer in obje
plt.figure(figsize=(15,8))
for i in range(object[0,:,:].shape[0]):
    for j in range(object[0,:,:].shape[1]):
        spectra = object[:,i,j]
        plt.plot(wavelengths,spectra,color='black',alpha=0.01,linewidth=0.8)

# %%
object[0,:,:][1].shape
# Out:
# (100,)
